# %%
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import glob
import pickle
from scipy.linalg import hankel
from scipy.stats import norm, zscore
import statsmodels.api as sm
import matplotx
from matplotlib.backends.backend_pdf import PdfPages
plt.style.use(matplotx.styles.aura['dark'])

# %%
with open('test_data_dms_ind_492_0603.pickle', 'rb') as handle:
    data = pickle.load(handle)
print(data.keys())
n_neurons = len(data['spikes'])
print(f'n_neurons: {n_neurons}')
# Out:
# dict_keys(['nCues_RminusL', 'currMaze', 'laserON', 'trialStart', 'trialEnd', 'keyFrames', 'time', 'cueOnset_L', 'cueOnset_R', 'choice', 'trialType', 'spikes', 'timeSqueezedFR'])
# n_neurons: 173

# %%
neuron = 12

psth_figs = PdfPages("arm_enter_psth_dms.pdf")

for neuron in range(n_neurons):
    trial_indices = np.nonzero((data["currMaze"] > 7)*(data['laserON'] == 0))[0]
    print(f'number of trials: {trial_indices.size}')
    X = []
    y = []
    filt_len = 30
    sp_filt_len = 30
    bin_size = 0.35
    trial_id = []
    bin_positions = []
    bin_centers_all = []
    time_before = 1
    time_after = 1
    spikes_all = []

    for trial_idx in trial_indices:
        keyframes = data["keyFrames"][trial_idx]
        keyframe_times = data["time"][trial_idx][keyframes.astype(int)].tolist()
        trial_start = data["trialStart"][trial_idx]
        # trial_end = data["trialEnd"][trial_idx]
        # lcue_times = data["cueOnset_L"][trial_idx] 
        # rcue_times = data["cueOnset_R"][trial_idx]
        # trial_start = keyframe_times[0] + data["trialStart"][trial_idx]
        trial_end = keyframe_times[2] + trial_start
        # arm_enter = trial_start + keyframe_times[2]
        psth_center = trial_start + keyframe_times[1]
        lcue_times = data["cueOnset_L"][trial_idx] - keyframe_times[0] # remove keyframe subtraction if using all phases of trial
        rcue_times = data["cueOnset_R"][trial_idx] - keyframe_times[0]

        trial_length = trial_end - trial_start
        spikes = data["spikes"][neuron]
        spikes = spikes[(spikes > (psth_center-time_before)) * (spikes < (psth_center + time_after))]
        spikes -= psth_center
        spikes_all.append(spikes)


    fig, axs = plt.subplots(2, 2, figsize=(8, 8))
    axs = axs.ravel()
    bin_edges = np.arange(-14, 15, 7)
    n_ev_level, _ = np.histogram(data['nCues_RminusL'][trial_indices], bins=bin_edges)
    bin_edges[-1] +=0.001
    ev_level = np.digitize(data['nCues_RminusL'][trial_indices], bins=bin_edges) - 1
    max_count = []
    bin_size = 0.02
    for i, ax in enumerate(axs):
        ev_spikes = np.hstack([spikes_all[i] for i in np.nonzero(ev_level==i)[0]])
        time_bins = np.arange(-time_before, time_after, bin_size)
        n, _, = np.histogram(ev_spikes, time_bins)
        ax.bar(np.convolve(time_bins, [0.5, 0.5], mode='valid'), n/(n_ev_level[i] * bin_size), bin_size)
        max_count.append(n.max())
        ax.set_title(f'Evidence: {bin_edges[i]:.0f} to {bin_edges[i+1]:.0f}')
        ax.set_ylabel('Spikes/s')

    max_count = np.max(max_count)
    max_count *= 1.05
    for ax in axs:
        ax.set_ylim([0, max_count])
    plt.suptitle(f'PSTH centered at arm enter | neuron {neuron}')
    plt.tight_layout()

    psth_figs.savefig(fig)
    plt.close(fig)

    print(f'completed neuron {neuron}')
    
psth_figs.close()
# Out:
# number of trials: 165
# completed neuron 0
# number of trials: 165
# completed neuron 1
# number of trials: 165
# completed neuron 2
# number of trials: 165
# completed neuron 3
# number of trials: 165
# completed neuron 4
# number of trials: 165
# completed neuron 5
# number of trials: 165
# completed neuron 6
# number of trials: 165
# completed neuron 7
# number of trials: 165
# completed neuron 8
# number of trials: 165
# completed neuron 9
# number of trials: 165
# completed neuron 10
# number of trials: 165
# completed neuron 11
# number of trials: 165
# completed neuron 12
# number of trials: 165
# completed neuron 13
# number of trials: 165
# completed neuron 14
# number of trials: 165
# completed neuron 15
# number of trials: 165
# completed neuron 16
# number of trials: 165
# completed neuron 17
# number of trials: 165
# completed neuron 18
# number of trials: 165
# completed neuron 19
# number of trials: 165
# /tmp/ipykernel_63652/3265441466.py:61: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax.set_ylim([0, max_count])
# completed neuron 20
# number of trials: 165
# completed neuron 21
# number of trials: 165
# completed neuron 22
# number of trials: 165
# completed neuron 23
# number of trials: 165
# completed neuron 24
# number of trials: 165
# completed neuron 25
# number of trials: 165
# completed neuron 26
# number of trials: 165
# completed neuron 27
# number of trials: 165
# completed neuron 28
# number of trials: 165
# completed neuron 29
# number of trials: 165
# completed neuron 30
# number of trials: 165
# completed neuron 31
# number of trials: 165
# completed neuron 32
# number of trials: 165
# completed neuron 33
# number of trials: 165
# completed neuron 34
# number of trials: 165
# completed neuron 35
# number of trials: 165
# completed neuron 36
# number of trials: 165
# completed neuron 37
# number of trials: 165
# completed neuron 38
# number of trials: 165
# completed neuron 39
# number of trials: 165
# completed neuron 40
# number of trials: 165
# completed neuron 41
# number of trials: 165
# completed neuron 42
# number of trials: 165
# completed neuron 43
# number of trials: 165
# completed neuron 44
# number of trials: 165
# completed neuron 45
# number of trials: 165
# completed neuron 46
# number of trials: 165
# completed neuron 47
# number of trials: 165
# completed neuron 48
# number of trials: 165
# completed neuron 49
# number of trials: 165
# completed neuron 50
# number of trials: 165
# completed neuron 51
# number of trials: 165
# completed neuron 52
# number of trials: 165
# completed neuron 53
# number of trials: 165
# completed neuron 54
# number of trials: 165
# completed neuron 55
# number of trials: 165
# completed neuron 56
# number of trials: 165
# completed neuron 57
# number of trials: 165
# completed neuron 58
# number of trials: 165
# completed neuron 59
# number of trials: 165
# completed neuron 60
# number of trials: 165
# completed neuron 61
# number of trials: 165
# completed neuron 62
# number of trials: 165
# completed neuron 63
# number of trials: 165
# completed neuron 64
# number of trials: 165
# completed neuron 65
# number of trials: 165
# completed neuron 66
# number of trials: 165
# completed neuron 67
# number of trials: 165
# completed neuron 68
# number of trials: 165
# completed neuron 69
# number of trials: 165
# completed neuron 70
# number of trials: 165
# completed neuron 71
# number of trials: 165
# completed neuron 72
# number of trials: 165
# completed neuron 73
# number of trials: 165
# completed neuron 74
# number of trials: 165
# completed neuron 75
# number of trials: 165
# completed neuron 76
# number of trials: 165
# completed neuron 77
# number of trials: 165
# completed neuron 78
# number of trials: 165
# completed neuron 79
# number of trials: 165
# completed neuron 80
# number of trials: 165
# completed neuron 81
# number of trials: 165
# completed neuron 82
# number of trials: 165
# completed neuron 83
# number of trials: 165
# completed neuron 84
# number of trials: 165
# completed neuron 85
# number of trials: 165
# completed neuron 86
# number of trials: 165
# completed neuron 87
# number of trials: 165
# completed neuron 88
# number of trials: 165
# completed neuron 89
# number of trials: 165
# completed neuron 90
# number of trials: 165
# completed neuron 91
# number of trials: 165
# completed neuron 92
# number of trials: 165
# completed neuron 93
# number of trials: 165
# completed neuron 94
# number of trials: 165
# completed neuron 95
# number of trials: 165
# completed neuron 96
# number of trials: 165
# completed neuron 97
# number of trials: 165
# completed neuron 98
# number of trials: 165
# completed neuron 99
# number of trials: 165
# completed neuron 100
# number of trials: 165
# completed neuron 101
# number of trials: 165
# completed neuron 102
# number of trials: 165
# completed neuron 103
# number of trials: 165
# completed neuron 104
# number of trials: 165
# completed neuron 105
# number of trials: 165
# completed neuron 106
# number of trials: 165
# completed neuron 107
# number of trials: 165
# completed neuron 108
# number of trials: 165
# completed neuron 109
# number of trials: 165
# completed neuron 110
# number of trials: 165
# completed neuron 111
# number of trials: 165
# completed neuron 112
# number of trials: 165
# completed neuron 113
# number of trials: 165
# completed neuron 114
# number of trials: 165
# completed neuron 115
# number of trials: 165
# completed neuron 116
# number of trials: 165
# completed neuron 117
# number of trials: 165
# completed neuron 118
# number of trials: 165
# completed neuron 119
# number of trials: 165
# completed neuron 120
# number of trials: 165
# completed neuron 121
# number of trials: 165
# completed neuron 122
# number of trials: 165
# completed neuron 123
# number of trials: 165
# completed neuron 124
# number of trials: 165
# completed neuron 125
# number of trials: 165
# completed neuron 126
# number of trials: 165
# completed neuron 127
# number of trials: 165
# completed neuron 128
# number of trials: 165
# completed neuron 129
# number of trials: 165
# completed neuron 130
# number of trials: 165
# completed neuron 131
# number of trials: 165
# completed neuron 132
# number of trials: 165
# completed neuron 133
# number of trials: 165
# completed neuron 134
# number of trials: 165
# completed neuron 135
# number of trials: 165
# completed neuron 136
# number of trials: 165
# completed neuron 137
# number of trials: 165
# completed neuron 138
# number of trials: 165
# completed neuron 139
# number of trials: 165
# completed neuron 140
# number of trials: 165
# completed neuron 141
# number of trials: 165
# completed neuron 142
# number of trials: 165
# completed neuron 143
# number of trials: 165
# completed neuron 144
# number of trials: 165
# completed neuron 145
# number of trials: 165
# completed neuron 146
# number of trials: 165
# completed neuron 147
# number of trials: 165
# completed neuron 148
# number of trials: 165
# completed neuron 149
# number of trials: 165
# completed neuron 150
# number of trials: 165
# completed neuron 151
# number of trials: 165
# completed neuron 152
# number of trials: 165
# completed neuron 153
# number of trials: 165
# completed neuron 154
# number of trials: 165
# completed neuron 155
# number of trials: 165
# completed neuron 156
# number of trials: 165
# completed neuron 157
# number of trials: 165
# completed neuron 158
# number of trials: 165
# completed neuron 159
# number of trials: 165
# completed neuron 160
# number of trials: 165
# completed neuron 161
# number of trials: 165
# completed neuron 162
# number of trials: 165
# completed neuron 163
# number of trials: 165
# completed neuron 164
# number of trials: 165
# completed neuron 165
# number of trials: 165
# completed neuron 166
# number of trials: 165
# completed neuron 167
# number of trials: 165
# completed neuron 168
# number of trials: 165
# completed neuron 169
# number of trials: 165
# completed neuron 170
# number of trials: 165
# completed neuron 171
# number of trials: 165
# completed neuron 172

# %%
time_before = 0
time_after = 0.5
psth_figs = PdfPages("tower_psth_dms.pdf")

for neuron in range(n_neurons):
    spikes_left = []
    spikes_right = []
    for trial_idx in trial_indices:
        keyframes = data["keyFrames"][trial_idx]
        keyframe_times = data["time"][trial_idx][keyframes.astype(int)].tolist()
        trial_start = data["trialStart"][trial_idx]
        # trial_end = data["trialEnd"][trial_idx]
        # lcue_times = data["cueOnset_L"][trial_idx] 
        # rcue_times = data["cueOnset_R"][trial_idx]
        # trial_start = keyframe_times[0] + data["trialStart"][trial_idx]
        trial_end = keyframe_times[2] + trial_start
        # arm_enter = trial_start + keyframe_times[2]
        # psth_center = trial_start + keyframe_times[1]
        lcue_times = data["cueOnset_L"][trial_idx]# - keyframe_times[0] # remove keyframe subtraction if using all phases of trial
        rcue_times = data["cueOnset_R"][trial_idx] #- keyframe_times[0]
        trial_length = trial_end - trial_start
        for l in np.array([lcue_times]).reshape(-1, 1):
            spikes = data["spikes"][neuron]
            psth_center = l + trial_start
            spikes = spikes[(spikes > (psth_center-time_before)) * (spikes < (psth_center + time_after))]
            spikes -= psth_center
            spikes_left.append(spikes)

        for r in np.array([rcue_times]).reshape(-1, 1):
            spikes = data["spikes"][neuron]
            psth_center = r + trial_start
            spikes = spikes[(spikes > (psth_center-time_before)) * (spikes < (psth_center + time_after))]
            spikes -= psth_center
            spikes_right.append(spikes)

    fig, axs = plt.subplots(1, 2, figsize=(8, 4))
    bin_size = 0.01
    time_bins = np.arange(-time_before, time_after+0.01, bin_size)
    max_count = []
    for i, spikes in enumerate([spikes_left, spikes_right]):
        n, _ = np.histogram(np.hstack(spikes), time_bins)
        print(len(spikes))
        rate = n/(len(spikes) * bin_size)
        axs[i].bar(np.convolve(time_bins, [0.5, 0.5], mode='valid'), rate, bin_size)
        max_count.append(rate.max())
        axs[i].set_title('{} tower psth'.format(['left', 'right'][i]))
        axs[i].set_ylabel('Spikes/s')

    max_count = np.max(max_count)
    max_count *= 1.05
    for ax in axs:
        ax.set_ylim([0, max_count])
    plt.suptitle(f'PSTH centered at towers | neuron {neuron}')
    plt.tight_layout()
    psth_figs.savefig(fig)
    plt.close(fig)
    print(f'completed neuron {neuron}')
psth_figs.close()
# Out:
# 621
# 910
# completed neuron 0
# 621
# 910
# completed neuron 1
# 621
# 910
# completed neuron 2
# 621
# 910
# completed neuron 3
# 621
# 910
# completed neuron 4
# 621
# 910
# completed neuron 5
# 621
# 910
# completed neuron 6
# 621
# 910
# completed neuron 7
# 621
# 910
# completed neuron 8
# 621
# 910
# completed neuron 9
# 621
# 910
# completed neuron 10
# 621
# 910
# completed neuron 11
# 621
# 910
# completed neuron 12
# 621
# 910
# completed neuron 13
# 621
# 910
# completed neuron 14
# 621
# 910
# completed neuron 15
# 621
# 910
# completed neuron 16
# 621
# 910
# completed neuron 17
# 621
# 910
# completed neuron 18
# 621
# 910
# completed neuron 19
# 621
# 910
# completed neuron 20
# 621
# 910
# completed neuron 21
# 621
# 910
# completed neuron 22
# 621
# 910
# completed neuron 23
# 621
# 910
# completed neuron 24
# 621
# 910
# completed neuron 25
# 621
# 910
# completed neuron 26
# 621
# 910
# completed neuron 27
# 621
# 910
# completed neuron 28
# 621
# 910
# completed neuron 29
# 621
# 910
# completed neuron 30
# 621
# 910
# completed neuron 31
# 621
# 910
# completed neuron 32
# 621
# 910
# completed neuron 33
# 621
# 910
# completed neuron 34
# 621
# 910
# completed neuron 35
# 621
# 910
# completed neuron 36
# 621
# 910
# completed neuron 37
# 621
# 910
# completed neuron 38
# 621
# 910
# completed neuron 39
# 621
# 910
# completed neuron 40
# 621
# 910
# completed neuron 41
# 621
# 910
# completed neuron 42
# 621
# 910
# completed neuron 43
# 621
# 910
# completed neuron 44
# 621
# 910
# completed neuron 45
# 621
# 910
# completed neuron 46
# 621
# 910
# completed neuron 47
# 621
# 910
# completed neuron 48
# 621
# 910
# completed neuron 49
# 621
# 910
# completed neuron 50
# 621
# 910
# completed neuron 51
# 621
# 910
# completed neuron 52
# 621
# 910
# completed neuron 53
# 621
# 910
# completed neuron 54
# 621
# 910
# completed neuron 55
# 621
# 910
# completed neuron 56
# 621
# 910
# completed neuron 57
# 621
# 910
# completed neuron 58
# 621
# 910
# completed neuron 59
# 621
# 910
# completed neuron 60
# 621
# 910
# completed neuron 61
# 621
# 910
# completed neuron 62
# 621
# 910
# completed neuron 63
# 621
# 910
# completed neuron 64
# 621
# 910
# completed neuron 65
# 621
# 910
# completed neuron 66
# 621
# 910
# completed neuron 67
# 621
# 910
# completed neuron 68
# 621
# 910
# completed neuron 69
# 621
# 910
# completed neuron 70
# 621
# 910
# completed neuron 71
# 621
# 910
# completed neuron 72
# 621
# 910
# completed neuron 73
# 621
# 910
# completed neuron 74
# 621
# 910
# completed neuron 75
# 621
# 910
# completed neuron 76
# 621
# 910
# completed neuron 77
# 621
# 910
# completed neuron 78
# 621
# 910
# completed neuron 79
# 621
# 910
# completed neuron 80
# 621
# 910
# completed neuron 81
# 621
# 910
# completed neuron 82
# 621
# 910
# completed neuron 83
# 621
# 910
# completed neuron 84
# 621
# 910
# completed neuron 85
# 621
# 910
# completed neuron 86
# 621
# 910
# completed neuron 87
# 621
# 910
# completed neuron 88
# 621
# 910
# completed neuron 89
# 621
# 910
# completed neuron 90
# 621
# 910
# completed neuron 91
# 621
# 910
# completed neuron 92
# 621
# 910
# completed neuron 93
# 621
# 910
# completed neuron 94
# 621
# 910
# completed neuron 95
# 621
# 910
# completed neuron 96
# 621
# 910
# completed neuron 97
# 621
# 910
# completed neuron 98
# 621
# 910
# completed neuron 99
# 621
# 910
# completed neuron 100
# 621
# 910
# completed neuron 101
# 621
# 910
# completed neuron 102
# 621
# 910
# completed neuron 103
# 621
# 910
# completed neuron 104
# 621
# 910
# completed neuron 105
# 621
# 910
# completed neuron 106
# 621
# 910
# completed neuron 107
# 621
# 910
# completed neuron 108
# 621
# 910
# completed neuron 109
# 621
# 910
# completed neuron 110
# 621
# 910
# completed neuron 111
# 621
# 910
# completed neuron 112
# 621
# 910
# completed neuron 113
# 621
# 910
# completed neuron 114
# 621
# 910
# completed neuron 115
# 621
# 910
# completed neuron 116
# 621
# 910
# completed neuron 117
# 621
# 910
# completed neuron 118
# 621
# 910
# completed neuron 119
# 621
# 910
# completed neuron 120
# 621
# 910
# completed neuron 121
# 621
# 910
# completed neuron 122
# 621
# 910
# completed neuron 123
# 621
# 910
# completed neuron 124
# 621
# 910
# completed neuron 125
# 621
# 910
# completed neuron 126
# 621
# 910
# completed neuron 127
# 621
# 910
# completed neuron 128
# 621
# 910
# completed neuron 129
# 621
# 910
# completed neuron 130
# 621
# 910
# completed neuron 131
# 621
# 910
# completed neuron 132
# 621
# 910
# completed neuron 133
# 621
# 910
# completed neuron 134
# 621
# 910
# completed neuron 135
# 621
# 910
# completed neuron 136
# 621
# 910
# completed neuron 137
# 621
# 910
# completed neuron 138
# 621
# 910
# completed neuron 139
# 621
# 910
# completed neuron 140
# 621
# 910
# completed neuron 141
# 621
# 910
# completed neuron 142
# 621
# 910
# completed neuron 143
# 621
# 910
# completed neuron 144
# 621
# 910
# completed neuron 145
# 621
# 910
# completed neuron 146
# 621
# 910
# completed neuron 147
# 621
# 910
# completed neuron 148
# 621
# 910
# completed neuron 149
# 621
# 910
# completed neuron 150
# 621
# 910
# completed neuron 151
# 621
# 910
# completed neuron 152
# 621
# 910
# completed neuron 153
# 621
# 910
# completed neuron 154
# 621
# 910
# completed neuron 155
# 621
# 910
# completed neuron 156
# 621
# 910
# completed neuron 157
# 621
# 910
# completed neuron 158
# 621
# 910
# completed neuron 159
# 621
# 910
# completed neuron 160
# 621
# 910
# completed neuron 161
# 621
# 910
# completed neuron 162
# 621
# 910
# completed neuron 163
# 621
# 910
# completed neuron 164
# 621
# 910
# completed neuron 165
# 621
# 910
# completed neuron 166
# 621
# 910
# completed neuron 167
# 621
# 910
# completed neuron 168
# 621
# 910
# completed neuron 169
# 621
# 910
# completed neuron 170
# 621
# 910
# completed neuron 171
# 621
# 910
# completed neuron 172

# %%
l
# Out:
# array([1.3718512, 1.6384308, 2.3556488], dtype=float32)
